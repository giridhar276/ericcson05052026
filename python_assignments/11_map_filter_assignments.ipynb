# %% [markdown]
# # 11 Real-Time Assignments - Map and Filter
#
# Practice data transformation and filtering using map() and filter().

# %% [markdown]
# ## Assignment 1: Apply Salary Hike
#
# ### Scenario
# HR wants to apply 10% salary hike to all employees.
#
# ### Task
# Use map() to create updated salary list.
#
# ### Expected Output
# Each salary should increase by 10%.

# %%
# Create a list of salaries.
salaries = [45000, 55000, 65000, 70000]

# Use map() and lambda to apply 10 percent hike.

# Print updated salaries.

# %% [markdown]
# ## Assignment 2: Filter High Value Orders
#
# ### Scenario
# An e-commerce team wants orders above 10000.
#
# ### Task
# Use filter() to select order amounts greater than 10000.
#
# ### Expected Output
# Only high value orders should be printed.

# %%
# Create a list of order amounts.
orders = [500, 15000, 2500, 22000, 8000]

# Use filter() and lambda.

# Print high value orders.

# %% [markdown]
# ## Assignment 3: Clean and Format Names
#
# ### Scenario
# Names from a form need to be cleaned and formatted.
#
# ### Task
# Use map() to strip spaces and convert names to title case.
#
# ### Expected Output
# Names should be clean and title cased.

# %%
# Create a list of raw names.
names = [" asha rao ", "RAVI kumar", " meena sharma "]

# Use map() and lambda to clean names.

# Print cleaned names.
