# %% [markdown]
# # 13 Real-Time Assignments - File Handling with Context Manager
#
# Practice file handling using the recommended with open() approach.

# %% [markdown]
# ## Assignment 1: Read Employee File Using Context Manager
#
# ### Scenario
# You want to read employee.csv safely without manually closing the file.
#
# ### Task
# Use with open() and read() to display complete file content.
#
# ### Expected Output
# File should be read and closed automatically.

# %%
# Open employee.csv using with open().

# Read complete file content.

# Print content.

# %% [markdown]
# ## Assignment 2: Filter IT Employees
#
# ### Scenario
# HR wants a separate file containing only IT employees.
#
# ### Task
# Use with open() to read employee.csv and write IT employees to it_employees.txt.
#
# ### Expected Output
# it_employees.txt should contain only IT department employees.

# %%
# Open employee.csv using context manager for reading.

# Read all lines.

# Open it_employees.txt using context manager for writing.

# Write header.

# Loop through employee records.

# Check department column.

# Write only IT employees.

# %% [markdown]
# ## Assignment 3: Calculate Total Sales
#
# ### Scenario
# A sales manager wants to know the total sales amount from sales.csv.
#
# ### Task
# Use with open() to read sales.csv and calculate total sales.
#
# ### Expected Output
# Print total sales amount.

# %%
# Create a variable to store total sales.

# Open sales.csv using context manager.

# Skip header.

# Loop through each order.

# Calculate quantity * price.

# Add to total sales.

# Print total sales.
