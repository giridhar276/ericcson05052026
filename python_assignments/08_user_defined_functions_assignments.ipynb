# %% [markdown]
# # 08 Real-Time Assignments - User Defined Functions
#
# Practice writing reusable functions for common business tasks.

# %% [markdown]
# ## Assignment 1: Salary Hike Function
#
# ### Scenario
# HR wants a reusable function to calculate salary after hike.
#
# ### Task
# Create a function that accepts salary and hike percentage, then returns updated salary.
#
# ### Expected Output
# For salary 50000 and hike 10%, output should be 55000.

# %%
# Define a function named calculate_hike.
# Function should accept salary and hike percentage.

# Call the function with sample values.

# Print updated salary.

# %% [markdown]
# ## Assignment 2: Billing Function
#
# ### Scenario
# A store wants to calculate total bill amount.
#
# ### Task
# Create a function that accepts price and quantity, then returns total amount.
#
# ### Expected Output
# For price 800 and quantity 3, output should be 2400.

# %%
# Define a function named calculate_bill.
# Function should accept price and quantity.

# Call the function.

# Print total bill.

# %% [markdown]
# ## Assignment 3: Employee Grade Function
#
# ### Scenario
# A company wants to assign employee grade based on performance score.
#
# ### Task
# Create a function that returns A, B, C, or D based on score.
#
# ### Expected Output
# Score >= 90: A, >= 75: B, >= 60: C, otherwise D.

# %%
# Define a function named get_grade.
# Function should accept performance score.

# Use if-elif-else inside the function.

# Call the function and print grade.
