# %% [markdown]
# # 10 Real-Time Assignments - Lambda Functions
#
# Practice lambda functions from simple to complex use cases.

# %% [markdown]
# ## Assignment 1: Quick Tax Calculator
#
# ### Scenario
# A billing system wants a one-line function to calculate 18% GST.
#
# ### Task
# Use lambda to calculate GST amount.
#
# ### Expected Output
# For 1000, GST should be 180.

# %%
# Create a lambda function to calculate 18 percent GST.

# Call lambda with amount 1000.

# Print GST amount.

# %% [markdown]
# ## Assignment 2: Sort Employees by Salary
#
# ### Scenario
# HR wants employee records sorted by salary.
#
# ### Task
# Use sorted() with lambda to sort employees by salary.
#
# ### Expected Output
# Employees should be sorted by salary.

# %%
# Create a list of employee tuples.
employees = [("Asha", 45000), ("Ravi", 65000), ("Meena", 55000)]

# Sort employees by salary using lambda.

# Print sorted employees.

# %% [markdown]
# ## Assignment 3: Categorize Transaction
#
# ### Scenario
# A finance app wants to categorize transaction as high or low value.
#
# ### Task
# Use lambda with if-else to return High if amount > 5000 else Low.
#
# ### Expected Output
# Amount 7000 should be High.

# %%
# Create a lambda function to categorize transaction.

# Test it with different transaction values.

# Print result.
