# %% [markdown]
# # 09 Real-Time Assignments - Different Ways of Passing Arguments
#
# Practice positional, keyword, default, *args, and **kwargs arguments.

# %% [markdown]
# ## Assignment 1: Employee Joining Details
#
# ### Scenario
# HR wants to print employee joining details.
#
# ### Task
# Create a function and call it using positional and keyword arguments.
#
# ### Expected Output
# Employee details should be printed correctly.

# %%
# Define a function that accepts name, department, and city.

# Call the function using positional arguments.

# Call the function using keyword arguments.

# %% [markdown]
# ## Assignment 2: Total Expense Calculator
#
# ### Scenario
# A team lead wants to calculate total expenses from any number of values.
#
# ### Task
# Use *args to accept multiple expense values and calculate total.
#
# ### Expected Output
# Function should work for any number of expense values.

# %%
# Define a function using *args.

# Add all expense values.

# Return total expense.

# Call function with sample values.

# %% [markdown]
# ## Assignment 3: Dynamic Employee Profile
#
# ### Scenario
# Employee profile may contain different fields for different employees.
#
# ### Task
# Use **kwargs to print dynamic employee details.
#
# ### Expected Output
# All key-value pairs should be printed.

# %%
# Define a function using **kwargs.

# Loop through kwargs and print key-value pairs.

# Call function with different employee details.
