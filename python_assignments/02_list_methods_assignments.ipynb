# %% [markdown]
# # 02 Real-Time Assignments - List Methods
#
# Practice list operations used in daily programming tasks.

# %% [markdown]
# ## Assignment 1: Training Attendance Tracker
#
# ### Scenario
# You are tracking participants attending a Python training.
#
# ### Task
# Add new participants, remove absent participants, and sort the final attendance list.
#
# ### Expected Output
# Final participant list should be sorted alphabetically.

# %%
# Create a list of participants.
participants = ["Asha", "Ravi", "Meena", "Arjun"]

# Add two new participants.
# Hint: Use append() or extend().

# Remove one absent participant.
# Hint: Use remove().

# Sort the final participant list.
# Hint: Use sort().

# Print final list.

# %% [markdown]
# ## Assignment 2: Top 3 Scores
#
# ### Scenario
# A trainer wants to find the top 3 quiz scores from a list of marks.
#
# ### Task
# Sort scores in descending order and display the top 3 scores.
#
# ### Expected Output
# For `[78, 92, 65, 88, 95]`, top 3 should be `[95, 92, 88]`.

# %%
# Create a list of quiz scores.
scores = [78, 92, 65, 88, 95, 70, 82]

# Sort the list in descending order.
# Hint: Use sort(reverse=True).

# Display only top 3 scores.
# Hint: Use slicing.

# %% [markdown]
# ## Assignment 3: Remove Duplicate Course Names
#
# ### Scenario
# A learning portal has duplicate course names in a list.
#
# ### Task
# Remove duplicates and display unique courses.
#
# ### Expected Output
# Each course should appear only once.

# %%
# Create a list with duplicate course names.
courses = ["Python", "SQL", "Python", "Power BI", "SQL", "Excel"]

# Create an empty list for unique courses.
unique_courses = []

# Write your logic below.
# Hint: Use a loop and membership check.
