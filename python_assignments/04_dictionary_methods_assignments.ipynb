# %% [markdown]
# # 04 Real-Time Assignments - Dictionary Methods
#
# Practice dictionary tasks commonly used for employee, product, and configuration data.

# %% [markdown]
# ## Assignment 1: Employee Profile Update
#
# ### Scenario
# HR wants to update employee salary and add city information.
#
# ### Task
# Update salary, add city, and print all key-value pairs.
#
# ### Expected Output
# Dictionary should contain updated salary and city.

# %%
# Create an employee dictionary.
employee = {"id": 101, "name": "Asha", "department": "HR", "salary": 45000}

# Update salary to 50000.
# Hint: Use update() or direct assignment.

# Add city as Hyderabad.

# Print each key and value.
# Hint: Use items().

# %% [markdown]
# ## Assignment 2: Product Price Lookup
#
# ### Scenario
# A billing system needs to safely fetch product prices.
#
# ### Task
# Use get() to fetch price. If product is missing, return `Product not found`.
#
# ### Expected Output
# Existing product should return price, missing product should return default message.

# %%
# Create a dictionary of products and prices.
products = {"Laptop": 65000, "Mouse": 800, "Keyboard": 1500}

# Get price of Laptop.

# Get price of Monitor with default message.
# Hint: Use get().

# Print both results.

# %% [markdown]
# ## Assignment 3: Department-Wise Employee Count
#
# ### Scenario
# You have a list of employee departments and want to count employees in each department.
#
# ### Task
# Create a dictionary where key is department and value is count.
#
# ### Expected Output
# {'IT': 3, 'HR': 2, ...}

# %%
# Create a list of departments.
departments = ["IT", "HR", "IT", "Finance", "HR", "IT", "Sales"]

# Create an empty dictionary.
department_count = {}

# Write your logic below.
# Hint: Use get() to handle missing keys.
