# %% [markdown]
# # 01 Real-Time Assignments - String Methods
#
# Practice real-time string processing tasks such as cleaning names, validating IDs, and formatting messages.

# %% [markdown]
# ## Assignment 1: Clean Customer Names
#
# ### Scenario
# You received customer names from a registration form. Some names have extra spaces and inconsistent letter cases.
#
# ### Task
# Clean each name by removing extra spaces and converting it into title case.
#
# ### Expected Output
# Input: `'   asha rao   '` → Output: `'Asha Rao'`

# %%
# Create a list of customer names with unwanted spaces and inconsistent cases.
customer_names = ["   asha rao   ", "RAVI kumar", "  meena SHARMA  ", "arjun reddy"]

# Create an empty list to store cleaned names.
cleaned_names = []

# Write your logic below.
# Hint: Use strip() and title().

# %% [markdown]
# ## Assignment 2: Generate Email IDs
#
# ### Scenario
# An HR team wants to generate company email IDs from employee names.
#
# ### Task
# Convert names to lowercase, replace spaces with dots, and add `@company.com`.
#
# ### Expected Output
# Input: `'Asha Rao'` → Output: `'asha.rao@company.com'`

# %%
# Create a list of employee names.
employees = ["Asha Rao", "Ravi Kumar", "Meena Sharma", "Arjun Reddy"]

# Create an empty list to store email IDs.
email_ids = []

# Write your logic below.
# Hint: Use lower(), replace(), and string concatenation.

# %% [markdown]
# ## Assignment 3: Validate Product Codes
#
# ### Scenario
# A retail system accepts product codes only if they start with `PRD` and contain only letters and numbers.
#
# ### Task
# Check whether each product code is valid or invalid.
#
# ### Expected Output
# `PRD1001` is valid, `prd-2001` is invalid.

# %%
# Create a list of product codes.
product_codes = ["PRD1001", "PRD2002", "prd-3003", "ITEM4004", "PRD5005"]

# Write your logic below.
# Hint: Use startswith(), isalnum(), and upper() if required.
