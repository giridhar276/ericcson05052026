# %% [markdown]
# # Python Foundation Real-Time Assignments - Combined List
#
# Use this notebook as a master assignment sheet for classroom practice.
#
# Datasets included:
# - employee.csv
# - sales.csv

# %% [markdown]
# ## 1. String Methods
# Open the corresponding assignment notebook `01_..._assignments.ipynb` and complete all tasks.

# %% [markdown]
# ## 2. List Methods
# Open the corresponding assignment notebook `02_..._assignments.ipynb` and complete all tasks.

# %% [markdown]
# ## 3. Tuple Methods
# Open the corresponding assignment notebook `03_..._assignments.ipynb` and complete all tasks.

# %% [markdown]
# ## 4. Dictionary Methods
# Open the corresponding assignment notebook `04_..._assignments.ipynb` and complete all tasks.

# %% [markdown]
# ## 5. Set Methods
# Open the corresponding assignment notebook `05_..._assignments.ipynb` and complete all tasks.

# %% [markdown]
# ## 6. Conditions
# Open the corresponding assignment notebook `06_..._assignments.ipynb` and complete all tasks.

# %% [markdown]
# ## 7. Loop Statements
# Open the corresponding assignment notebook `07_..._assignments.ipynb` and complete all tasks.

# %% [markdown]
# ## 8. User Defined Functions
# Open the corresponding assignment notebook `08_..._assignments.ipynb` and complete all tasks.

# %% [markdown]
# ## 9. Passing Arguments
# Open the corresponding assignment notebook `09_..._assignments.ipynb` and complete all tasks.

# %% [markdown]
# ## 10. Lambda Functions
# Open the corresponding assignment notebook `10_..._assignments.ipynb` and complete all tasks.

# %% [markdown]
# ## 11. Map and Filter
# Open the corresponding assignment notebook `11_..._assignments.ipynb` and complete all tasks.

# %% [markdown]
# ## 12. File Handling
# Open the corresponding assignment notebook `12_..._assignments.ipynb` and complete all tasks.

# %% [markdown]
# ## 13. Context Manager
# Open the corresponding assignment notebook `13_..._assignments.ipynb` and complete all tasks.
