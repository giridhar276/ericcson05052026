# %% [markdown]
# # 05 Real-Time Assignments - Set Methods
#
# Practice set operations for unique data, common records, and differences.

# %% [markdown]
# ## Assignment 1: Unique Skill List
#
# ### Scenario
# Employees have submitted duplicate skills. HR needs a unique skill list.
#
# ### Task
# Convert the list into a set and display unique skills.
#
# ### Expected Output
# Duplicate skills should be removed.

# %%
# Create a list with duplicate skills.
skills = ["Python", "SQL", "Python", "Excel", "SQL", "Power BI"]

# Convert list to set.
# Hint: Use set().

# Print unique skills.

# %% [markdown]
# ## Assignment 2: Common Students in Two Courses
#
# ### Scenario
# A trainer wants to identify students enrolled in both Python and SQL courses.
#
# ### Task
# Find common students using intersection().
#
# ### Expected Output
# Print students common in both sets.

# %%
# Create Python students set.
python_students = {"Asha", "Ravi", "Meena", "Arjun"}

# Create SQL students set.
sql_students = {"Ravi", "Kavya", "Arjun", "Neha"}

# Find common students.
# Hint: Use intersection().

# Print common students.

# %% [markdown]
# ## Assignment 3: Students Only in Python Course
#
# ### Scenario
# A trainer wants to find students who joined Python but not SQL.
#
# ### Task
# Use difference() to find students only in Python course.
#
# ### Expected Output
# Print students present only in Python set.

# %%
# Create Python students set.
python_students = {"Asha", "Ravi", "Meena", "Arjun"}

# Create SQL students set.
sql_students = {"Ravi", "Kavya", "Arjun", "Neha"}

# Find students only in Python course.
# Hint: Use difference().

# Print result.
