# %% [markdown]
# # 03 Real-Time Assignments - Tuple Methods
#
# Practice tuple-based tasks where data should not be changed accidentally.

# %% [markdown]
# ## Assignment 1: Employee Record Reader
#
# ### Scenario
# Employee records are stored as tuples because they should not be modified.
#
# ### Task
# Access employee ID, name, department, and salary from a tuple.
#
# ### Expected Output
# Print each employee field separately.

# %%
# Create an employee tuple.
employee = (101, "Asha", "HR", 45000)

# Print employee ID.

# Print employee name.

# Print employee department.

# Print employee salary.

# %% [markdown]
# ## Assignment 2: Count City Occurrences
#
# ### Scenario
# A company wants to know how many employees are from Hyderabad.
#
# ### Task
# Use tuple count() method to count Hyderabad occurrences.
#
# ### Expected Output
# Hyderabad count should be printed.

# %%
# Create a tuple of employee cities.
cities = ("Hyderabad", "Chennai", "Hyderabad", "Pune", "Bengaluru", "Hyderabad")

# Count Hyderabad occurrences.
# Hint: Use count().

# Print the result.

# %% [markdown]
# ## Assignment 3: Find First Position of a Department
#
# ### Scenario
# You need to find where the IT department first appears in a tuple.
#
# ### Task
# Use index() to find the first position of `IT`.
#
# ### Expected Output
# Print index position of IT.

# %%
# Create a tuple of departments.
departments = ("HR", "Finance", "IT", "Sales", "IT")

# Find first index of IT.
# Hint: Use index().

# Print the index.
