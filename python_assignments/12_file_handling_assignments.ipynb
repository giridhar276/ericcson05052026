# %% [markdown]
# # 12 Real-Time Assignments - File Handling
#
# Practice file handling using employee.csv and sales.csv.

# %% [markdown]
# ## Assignment 1: Read Complete Employee File
#
# ### Scenario
# You need to read the complete employee.csv file.
#
# ### Task
# Use open() and read() to display complete file content.
#
# ### Expected Output
# Complete CSV content should be displayed.

# %%
# Open employee.csv in read mode.

# Use read() to read complete content.

# Print content.

# Close the file.

# %% [markdown]
# ## Assignment 2: Read Employee File Line by Line
#
# ### Scenario
# You need to process employee records one by one.
#
# ### Task
# Use readlines() and loop through all employee rows.
#
# ### Expected Output
# Each employee row should be printed separately.

# %%
# Open employee.csv in read mode.

# Use readlines() to read all lines.

# Loop through each line.

# Print each line after strip().

# Close the file.

# %% [markdown]
# ## Assignment 3: Create High Salary Report
#
# ### Scenario
# Management wants a report of employees with salary greater than 60000.
#
# ### Task
# Read employee.csv and write high salary employees to high_salary_report.txt.
#
# ### Expected Output
# high_salary_report.txt should contain employees with salary greater than 60000.

# %%
# Open employee.csv in read mode.

# Read all lines.

# Open high_salary_report.txt in write mode.

# Write header into output file.

# Loop through employee records.

# Split each record by comma.

# Check salary greater than 60000.

# Write matching records to output file.

# Close both files.

# %% [markdown]
# ## Assignment 4: Create Sales Summary File
#
# ### Scenario
# A sales team wants total amount for each order.
#
# ### Task
# Read sales.csv, calculate quantity * price, and write result to sales_summary.txt.
#
# ### Expected Output
# sales_summary.txt should contain order ID, customer, and total amount.

# %%
# Open sales.csv in read mode.

# Read all lines.

# Open sales_summary.txt in write mode.

# Write header into sales_summary.txt.

# Loop through sales records except header.

# Split each row by comma.

# Calculate total amount as quantity * price.

# Write order ID, customer, and total amount.

# Close both files.
