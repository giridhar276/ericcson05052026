# %% [markdown]
# # 07 Real-Time Assignments - Loop Statements
#
# Practice for loops, while loops, break, continue, and nested loops with real-world examples.

# %% [markdown]
# ## Assignment 1: Print Employee Names
#
# ### Scenario
# You have a list of employees and need to print each employee name.
#
# ### Task
# Use a for loop to print all names.
#
# ### Expected Output
# Each employee name should print on a new line.

# %%
# Create a list of employee names.
employees = ["Asha", "Ravi", "Meena", "Arjun"]

# Use for loop to print names.

# %% [markdown]
# ## Assignment 2: Find First High Salary
#
# ### Scenario
# You need to stop searching once you find the first salary greater than 70000.
#
# ### Task
# Use break when salary greater than 70000 is found.
#
# ### Expected Output
# Print first high salary and stop loop.

# %%
# Create a list of salaries.
salaries = [45000, 55000, 65000, 72000, 80000]

# Use loop and break.

# %% [markdown]
# ## Assignment 3: Skip Invalid Transactions
#
# ### Scenario
# A transaction list has negative values. Negative values should be skipped.
#
# ### Task
# Use continue to skip negative transactions and print valid transactions only.
#
# ### Expected Output
# Only positive transaction values should be printed.

# %%
# Create a list of transactions.
transactions = [5000, -200, 3000, -100, 7000]

# Use loop and continue.
