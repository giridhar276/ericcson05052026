# %% [markdown]
# # 06 Real-Time Assignments - Conditions
#
# Practice decision-making scenarios using if, elif, else, and nested conditions.

# %% [markdown]
# ## Assignment 1: Loan Eligibility Checker
#
# ### Scenario
# A bank wants to check whether a customer is eligible for a personal loan.
#
# ### Task
# If salary is greater than 50000 and credit score is greater than 700, print eligible.
#
# ### Expected Output
# Print eligible or not eligible.

# %%
# Store customer salary.
salary = 60000

# Store customer credit score.
credit_score = 720

# Write condition to check loan eligibility.

# %% [markdown]
# ## Assignment 2: Employee Bonus Calculator
#
# ### Scenario
# A company gives bonuses based on experience.
#
# ### Task
# If experience >= 5 years, bonus is 20%; if >= 3 years, bonus is 10%; otherwise 5%.
#
# ### Expected Output
# Print bonus amount.

# %%
# Store employee salary.
salary = 50000

# Store employee experience.
experience = 4

# Write your bonus calculation logic using if-elif-else.

# %% [markdown]
# ## Assignment 3: Login Validation
#
# ### Scenario
# A simple application validates username and password.
#
# ### Task
# Use nested if to check username first, then password.
#
# ### Expected Output
# Print login successful, invalid username, or invalid password.

# %%
# Store username.
username = "admin"

# Store password.
password = "python123"

# Write nested if condition.
